# %%
# example of horizontal shift image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('assets/addi/fire/rescaled_image_0.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=[-200,200])
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# example of vertical shift image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('assets/addi/fire/rescaled_image_0.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(height_shift_range=0.2)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# example of horizontal flip image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(horizontal_flip=True)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image

# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(rotation_range=90)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# example of brighting image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('assets/addi/fire/rescaled_image_0.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(12):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-57db4520e2cc> in <module>
#      18 for i in range(12):
#      19         # define subplot
# ---> 20         pyplot.subplot(330 + 1 + i)
#      21         # generate batch of images
#      22         batch = it.next()
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# ...

# %% [markdown]
# # Combined

# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('assets/addi/fire/rescaled_image_0.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(brightness_range=[0.2,1.0], 
                             horizontal_flip=True, 
                             vertical_flip=True, 
                            width_shift_range=[-200,200], 
                           )
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
print(type(batch))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Saving images

# %%
from keras.preprocessing.image import array_to_img, save_img
def generate_images(list_of_paths, directory, generated_images_per_image ):
    counter = 0
    for path in list_of_paths:
        img = load_img(path)
# convert to numpy array
        data = img_to_array(img)
# expand dimension to one sample
        samples = expand_dims(data, 0)
# create image data augmentation generator
        datagen = ImageDataGenerator(brightness_range=[0.2,1.0], 
                             horizontal_flip=True, 
                             vertical_flip=True, 
                            width_shift_range=[-200,200], 
                           )
    # prepare iterator
        it = datagen.flow(samples, batch_size=1)
# generate samples and plot
        for i in range(generated_images_per_image):
	# define subplot
            
	# generate batch of images
            batch = it.next()
            img = array_to_img(batch[0], scale=True)
            print(directory + str(counter)+"_aug_test.jpg")
            save_img(directory + str(counter)+"_aug_test.jpg",img )
            counter += 1
	# convert to unsigned integers for viewing
    return None

# %%
image_list = ["assets/addi/fire/rescaled_image_0.jpg"]
directory  = "assets/addi/aug/"
aug_per_img = 5
generate_images(image_list, directory, aug_per_img)
# Out:
# assets/addi/aug/0aug_test.jpg
# assets/addi/aug/1aug_test.jpg
# assets/addi/aug/2aug_test.jpg
# assets/addi/aug/3aug_test.jpg
# assets/addi/aug/4aug_test.jpg

# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


df = pd.read_csv("fire_data.csv")
df = shuffle(df)
df = df.drop(list(df.columns)[0], axis=1)
X = df["file"]
list_files=df["file"].tolist()
directory  = "assets/addi/aug/"
aug_per_img = 5
generate_images(list_files, directory, aug_per_img)
# Out:
# assets/addi/aug/0_aug_test.jpg
# assets/addi/aug/1_aug_test.jpg
# assets/addi/aug/2_aug_test.jpg
# assets/addi/aug/3_aug_test.jpg
# assets/addi/aug/4_aug_test.jpg
# assets/addi/aug/5_aug_test.jpg
# assets/addi/aug/6_aug_test.jpg
# assets/addi/aug/7_aug_test.jpg
# assets/addi/aug/8_aug_test.jpg
# assets/addi/aug/9_aug_test.jpg
# assets/addi/aug/10_aug_test.jpg
# assets/addi/aug/11_aug_test.jpg
# assets/addi/aug/12_aug_test.jpg
# assets/addi/aug/13_aug_test.jpg
# assets/addi/aug/14_aug_test.jpg
# assets/addi/aug/15_aug_test.jpg
# assets/addi/aug/16_aug_test.jpg
# assets/addi/aug/17_aug_test.jpg
# assets/addi/aug/18_aug_test.jpg
# assets/addi/aug/19_aug_test.jpg
# assets/addi/aug/20_aug_test.jpg
# assets/addi/aug/21_aug_test.jpg
# assets/addi/aug/22_aug_test.jpg
# assets/addi/aug/23_aug_test.jpg
# assets/addi/aug/24_aug_test.jpg
# assets/addi/aug/25_aug_test.jpg
# assets/addi/aug/26_aug_test.jpg
# assets/addi/aug/27_aug_test.jpg
# assets/addi/aug/28_aug_test.jpg
# ...
