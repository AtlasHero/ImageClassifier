# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img =plt.imread('assets/addi/drone_shots/80755A11FC8B59C3FE307E06EEFDB263.JPG')

plt.figure(figsize=(15,15))

plt.subplot(321)
plt.imshow(img,cmap='gray')

plt.subplot(322)
img = cv2.imread('red.png',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-6af28d96807a> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 from matplotlib import pyplot as plt
#       4
#       5 img =plt.imread('assets/addi/drone_shots/80755A11FC8B59C3FE307E06EEFDB263.JPG')
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread('red.png')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread('red.png')
color = ('r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()
